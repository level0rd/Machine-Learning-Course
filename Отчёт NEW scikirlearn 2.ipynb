# %% [markdown]
# #    Отчет по тестовому заданию №5
# # по теме: "SVM with scikit-learn."
#
#
#
# ####     Генерация данных:
# ```python
# from sklearn.datasets.samples_generator import make_blobs
#
# x,y = make_blobs(n_samples=100, centers=2, n_features=2,
#                  random_state=0, cluster_std=0.4);
#     # center - Количество классов,  n - количетсво точек, cluster_std - расстояние стандартного отклонения
#
# print(x.shape) #Сколько признаков и сколько элементов
# plt.scatter(x[:,0],x[:,1], c=y, edgecolor="grey", s=50, cmap='coolwarm')
# ```
# Получившийся результат:
#
#
# ![1](Pictures/55.png)
#
# Предыдущий код с новыми параметрами:
#     centers=3, n_features=3 и получим
#
# ![2](Pictures/66.png)
#
#
#
# ####    Реализация методов опорных векторов:
# ```python
# clf = SVC(kernel='linear', C=1E10)
# clf.fit(X,y)
#
#
# def plot_svc_decision_function(model, ax=None, plot_support=True):
#     if ax is None:
#         ax = plt.gca()
#     xlim = ax.get_xlim(); # Граници
#     ylim = ax.get_ylim();
#
#     x = np.linspace(xlim[0],xlim[1],30)
#     y = np.linspace(ylim[0],ylim[1],30)
#
#     Y,X = np.meshgrid(y,x)
#     xy = np.vstack([X.ravel(),Y.ravel()]).T
#
#
#     P = model.decision_function(xy).reshape(X.shape)
#
#     ax.contour(X,Y,P,colors='k',
#               levels=[-1,0,1], alpha=0.5,
#               linestyles=['--','-','--'])
#
#     if plot_support:
#         ax.scatter(model.support_vectors_[:,0],
#                   model.support_vectors_[:,1],
#                   s=300,linewidth=1,facecolors='none');
#         ax.scatter(model.support_vectors_[:, 0],
#                    model.support_vectors_[:, 1],
#                    s= 300, linewidth=2, edgecolor='green',
#                    facecolors='none');
#
#     ax.set_xlim(xlim)
#     ax.set_ylim(ylim)
#
# plt.scatter(X[:,0],X[:,1],c=y,edgecolor='grey',s=50,cmap='coolwarm')
# plot_svc_decision_function(clf)
# ```
#
#
#
# ![3](Pictures/99.png)

# %% [markdown]
# # Литература
#
# * [scikit-learn:](https://scikit-learn.org/stable/modules/svm.html)
