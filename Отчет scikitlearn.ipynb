# %% [markdown]
# #    Отчет по тестовому заданию №4
# # по теме: "Задачи машинного обучения. Корреляция и линейная регрессия."
#     В тестовом задании было необходимо сначала воссоздать в *.csv статистику посещаемости сайта, а затем исследовать зависимость количества скачиваний программного продукта от количества посещений сайта используя библиотеки matplotlib, numpy и scikit-learn.
#     Созданный файл:
#
#    ![1](Pictures/Cites.png)
#
#     Реализация на языке Python:
#  ```python
# data = pd.read_csv('Data/down_views.csv')
# data
# downloads = np.array(data['downloads'])
# views = np.array(data['views'])
#
# reg = linear_model.LinearRegression()
#
# train_x = views[:,np.newaxis]
# downloads_100 = downloads
# train_y = downloads[:,np.newaxis]
#
# reg.fit(train_x,train_y)
#
# prediction_y = reg.predict(train_x)
#
# plt.figure(figsize=(5, 5), dpi=200)
# plt.scatter(views, downloads, edgecolor="red", s=50, cmap='coolwarm', label="Data from [1]");
#
# plt.plot(train_x, prediction_y, color="blue", linewidth=1, label="Liner model");
# plt.ylabel("Скачивания")
# plt.xlabel("Загрузки")
# plt.title("Зависимость зарегистрировавшихся на сайте от количества посещений за 10 дней")
# plt.legend()
# plt.show()
#
# ```
# ####    Вывод графика линейной регрессии на экран:
# ![1](Pictures/123123123.png)
#
#     Так же было необходимо разобрать пример реализации линейной регрессии с сайта https://scikit-learn.org.
#  ```python
#     # Load the diabetes dataset
# diabetes = datasets.load_diabetes()#загрузка данных
#
#
# # Use only one feature
# diabetes_X = diabetes.data[:, np.newaxis, 2]#Пропускаем первый столбец, расширяем массив
#
# # Split the data into training/testing sets
# diabetes_X_train = diabetes_X[:-20]#каждый 20
# diabetes_X_test = diabetes_X[-20:]#последние 20
#
# # Split the targets into training/testing sets
# diabetes_y_train = diabetes.target[:-20]#каждый 20
# diabetes_y_test = diabetes.target[-20:]#последние 20
#
# # Create linear regression object
# regr = linear_model.LinearRegression()#Создаем пустую модель Линейной регрессии
#
# # Train the model using the training sets
# regr.fit(diabetes_X_train, diabetes_y_train)#запускаем расчет параметров для указанных данных
#
# # Make predictions using the testing set
# diabetes_y_pred = regr.predict(diabetes_X_test)#прогнозирем целевые значения х
#
# # The coefficients
# print('Coefficients: \n', regr.coef_)#Выводим оценочные коэффициенты
# # The mean squared error
# print("Mean squared error: %.2f"
#       % mean_squared_error(diabetes_y_test, diabetes_y_pred))#Среднеквадратическая ошибка регрессии
# # Explained variance score: 1 is perfect prediction
# print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))#определяет коэффициент детерминации(оценивает регрессию от 0 до 1.0)
#
# # Plot outputs
# plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')#строим точки
# plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)#строим линию
#
# plt.xticks(())#получить текущее местополодение оси х
# plt.yticks(())#получить текущее местополодение оси у
#
# plt.show()
# ```
# ####    Рехультат выполнения кода:
# ![2](Pictures/12312313.png)
#
# # Литература
#
# * [HabraHabr:](https://habr.com/ru/company/nerepetitor/blog/250633/)
# * [scikit-learn:](https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html)
