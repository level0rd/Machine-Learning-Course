# %%
#Генерирует изотропные гауссовы капели для кластеризации.
#n_samples - общее количество точек, поровну разделенных между кластерами. 
#n_features - Количество функций для каждого образца.
#centers - Количество создаваемых центров или фиксированные местоположения центров.
#cluster_std- Стандартное отклонение кластеров.
#random_state - Определяет генерацию случайных чисел для создания набора данных
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt;

x,y = make_blobs(n_samples=1000, centers=3, n_features=2, 
                 random_state=0, cluster_std=0.5); 
    # center - Количество классов,  n - количетсво точек, cluster_std - расстояние стандартного отклонения
    #

print(x.shape) #Сколько признаков и сколько элементов
plt.title("make_blobs")
plt.scatter(x[:,0],x[:,1], c=y, edgecolor="grey", s=50, cmap='coolwarm')
# Out:
# (1000, 2)

# %%
#Создает массив с блочной структурой шахматной доски для кластеризации
#noise - количество шумов больше/меньше. Стандартное отклонение гауссовского шума.
#shuffle - перемешивание true/false. 
#random_state - Определяет генерацию случайных чисел для создания набора данных
#n_clusters - Количество кластеров строк и столбцов.

from sklearn.datasets.samples_generator import make_checkerboard

# https://scikit-learn.org/stable/auto_examples/bicluster/plot_spectral_coclustering.html#sphx-glr-auto-examples-bicluster-plot-spectral-coclustering-py
n_clusters = (4, 3)
data, rows, columns = make_checkerboard(
    shape=(300, 300), n_clusters=n_clusters, noise=0,
    shuffle=False, random_state=0)

plt.matshow(data, cmap=plt.cm.Blues)
plt.title("make_checkerboard")
data
# Out:
# array([[51.5331426 , 51.5331426 , 51.5331426 , ..., 20.64469833,
#         20.64469833, 20.64469833],
#        [51.5331426 , 51.5331426 , 51.5331426 , ..., 20.64469833,
#         20.64469833, 20.64469833],
#        [51.5331426 , 51.5331426 , 51.5331426 , ..., 20.64469833,
#         20.64469833, 20.64469833],
#        ...,
#        [79.68103205, 79.68103205, 79.68103205, ..., 61.1590554 ,
#         61.1590554 , 61.1590554 ],
#        [79.68103205, 79.68103205, 79.68103205, ..., 61.1590554 ,
#         61.1590554 , 61.1590554 ],
#        [79.68103205, 79.68103205, 79.68103205, ..., 61.1590554 ,
#         61.1590554 , 61.1590554 ]])

# %%
#Создает массив с постоянной диагональной структурой блоков для бикластеризации.
#n_clusters -количксвто кластеров
#noise - количество шумов больше/меньше. Стандартное отклонение гауссовского шума.
#shuffle - перемешивание true/false. 
#random_state - Определяет генерацию случайных чисел для создания набора данных
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_biclusters

# https://scikit-learn.org/stable/auto_examples/bicluster/plot_spectral_coclustering.html#sphx-glr-auto-examples-bicluster-plot-spectral-coclustering-py

data, rows, columns = make_biclusters(
    shape=(300, 300), n_clusters=5, noise=5,
    shuffle=False, random_state=0)

plt.matshow(data, cmap=plt.cm.Blues)
plt.title("make_biclusters")
data
# Out:
# array([[ 51.5757319 ,  56.55972725,  58.18246778, ...,  -2.58981343,
#           2.89899398,  -6.7686642 ],
#        [ 55.79558203,  58.80013477,  55.35263508, ...,  -1.41497175,
#          -3.2799709 ,   6.21064248],
#        [ 52.05043305,  63.61855062,  56.472263  , ...,  -7.49061145,
#           9.54450971,   3.42989718],
#        ...,
#        [  2.96957381,  10.05407575,  -7.85798359, ...,  44.17903127,
#          47.18611831,  47.27390074],
#        [ -4.55871438, -14.12124735, -11.06268131, ...,  45.86252493,
#          47.12698751,  45.18566039],
#        [  0.11249079,  -5.41797015,   6.12839887, ...,  48.82969145,
#          50.03185852,  43.55138377]])

# %%
#Рисует большой круг, состоящий из маленьких. Набор игрушечных данных для визуализации алгоритмов кластеризации и классификации.
#n_samples - Общее количество сгененрированных точек. Если нечетно, внутренний круг будет иметь одну точку больше, чем внешний круг.
#factor- Коэффициент масштабирования между внутренним и внешним кругом.
#noise - добавление к данным стандартного отклонения гаусовского шума
from sklearn.datasets.samples_generator import make_circles

n_samples = 1000
x,y = make_circles(n_samples=n_samples, factor=.5, noise=.05)

plt.scatter(x[:,0],x[:,1], c=y, edgecolor="grey", s=50, cmap='coolwarm')
plt.title("make_circles")
# Out:
# Text(0.5, 1.0, 'make_circles')

# %%
#Классификационных данных строится путем взятия многомерного стандартного нормального распределения 
#и определения классов, разделенных вложенными концентрическими многомерными сферами, 
#так чтобы примерно равное количество выборок находилось в каждом классе (квантили распределения).
#n_features - Количество функций для каждого образца.
#n_classes - Количество классов
import matplotlib.pyplot as plt

from sklearn.datasets import make_gaussian_quantiles

plt.figure(figsize=(8, 8))
plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)

plt.subplot(326)
#plt.title("Gaussian divided into three quantiles")
plt.title("make_gaussian_quantiles")
X1, Y1 = make_gaussian_quantiles(n_features=2, n_classes=3)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')

plt.show()

# %%
#Cоздает кластеры точек, распределенных вокруг вершин n-мерного гиперкуба, и назначает равное количество кластеров каждому классу.
#n_inforrative - количесвто вершин
#n_features - количество функций
#n_redundant - Количество избыточных функций. Функции генерируются как случайные линейные комбинации информативных функцций.
#n_clusters_per_class - количество кластеров в классе

import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

plt.figure(figsize=(8, 8))
plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)

plt.subplot(324)
plt.title("make_classification")
#plt.title("Multi-class, two informative features, one cluster",
#          fontsize='small')
X1, Y1 = make_classification(n_features=2, n_redundant=0, n_informative=2,
                             n_clusters_per_class=1, n_classes=3)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')

# %%
print(__doc__)

# Author: Peter Prettenhofer <peter.prettenhofer@gmail.com>
#
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn import ensemble
from sklearn import datasets


X, y = datasets.make_hastie_10_2(n_samples=12000, random_state=1)
X = X.astype(np.float32)

# map labels from {-1, 1} to {0, 1}
labels, y = np.unique(y, return_inverse=True)

X_train, X_test = X[:2000], X[2000:]
y_train, y_test = y[:2000], y[2000:]

original_params = {'n_estimators': 1000, 'max_leaf_nodes': 4, 'max_depth': None, 'random_state': 2,
                   'min_samples_split': 5}

plt.figure()

for label, color, setting in [('No shrinkage', 'orange',
                               {'learning_rate': 1.0, 'subsample': 1.0}),
                              ('learning_rate=0.1', 'turquoise',
                               {'learning_rate': 0.1, 'subsample': 1.0}),
                              ('subsample=0.5', 'blue',
                               {'learning_rate': 1.0, 'subsample': 0.5}),
                              ('learning_rate=0.1, subsample=0.5', 'gray',
                               {'learning_rate': 0.1, 'subsample': 0.5}),
                              ('learning_rate=0.1, max_features=2', 'magenta',
                               {'learning_rate': 0.1, 'max_features': 2})]:
    params = dict(original_params)
    params.update(setting)

    clf = ensemble.GradientBoostingClassifier(**params)
    clf.fit(X_train, y_train)

    # compute test set deviance
    test_deviance = np.zeros((params['n_estimators'],), dtype=np.float64)

    for i, y_pred in enumerate(clf.staged_decision_function(X_test)):
        # clf.loss_ assumes that y_test[i] in {0, 1}
        test_deviance[i] = clf.loss_(y_test, y_pred)

    plt.plot((np.arange(test_deviance.shape[0]) + 1)[::5], test_deviance[::5],
            '-', color=color, label=label)

plt.legend(loc='upper left')
plt.xlabel('Boosting Iterations')
plt.ylabel('Test Set Deviance')

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
#Создает два чередующихся полукруга. Набор игрушечных данных для визуализации алгоритмов кластеризации и классификации.
#n_samples - общее количество сгенерированных точек
#noise - добавление к данным стандартного отклонения гаусовского шума
from sklearn.datasets import make_moons

x,y = make_moons(n_samples=50, noise = 0)
plt.title("make_moons")
plt.scatter(x[:,0],x[:,1], c=y, edgecolor="grey", s=50, cmap='coolwarm')

# %%
#Создает случайную задачу классификации с несколькими метками.

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_multilabel_classification
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.cross_decomposition import CCA
#from sklearn.decomposition import PCA


def plot_hyperplane(clf, min_x, max_x, linestyle, label):
    # get the separating hyperplane
    w = clf.coef_[0]
    a = -w[0] / w[1]
    xx = np.linspace(min_x - 5, max_x + 5)  # make sure the line is long enough
    yy = a * xx - (clf.intercept_[0]) / w[1]
    plt.plot(xx, yy, linestyle, label=label)


def plot_subfigure(X, Y, subplot, title, transform):
    if transform == "pca":
        X = PCA(n_components=2).fit_transform(X)
    elif transform == "cca":
        X = CCA(n_components=2).fit(X, Y).transform(X)
    else:
        raise ValueError

    min_x = np.min(X[:, 0])
    max_x = np.max(X[:, 0])

    min_y = np.min(X[:, 1])
    max_y = np.max(X[:, 1])

    classif = OneVsRestClassifier(SVC(kernel='linear'))
    classif.fit(X, Y)

    plt.subplot(2, 2, subplot)
    plt.title(title)

    zero_class = np.where(Y[:, 0])
    one_class = np.where(Y[:, 1])
    plt.scatter(X[:, 0], X[:, 1], s=40, c='gray', edgecolors=(0, 0, 0))
    plt.scatter(X[zero_class, 0], X[zero_class, 1], s=160, edgecolors='b',
                facecolors='none', linewidths=2, label='Class 1')
    plt.scatter(X[one_class, 0], X[one_class, 1], s=80, edgecolors='orange',
                facecolors='none', linewidths=2, label='Class 2')

    plt.xticks(())
    plt.yticks(())

    plt.xlim(min_x - .5 * max_x, max_x + .5 * max_x)
    plt.ylim(min_y - .5 * max_y, max_y + .5 * max_y)
    if subplot == 2:
        plt.xlabel('First principal component')
        plt.ylabel('Second principal component')
        plt.legend(loc="upper left")


plt.figure(figsize=(16, 12))

X, Y = make_multilabel_classification(n_classes=2, n_labels=1,
                                      allow_unlabeled=True,
                                      random_state=1)

plot_subfigure(X, Y, 1, "make_multilabel_classification", "cca")

X, Y = make_multilabel_classification(n_classes=2, n_labels=1,
                                      allow_unlabeled=False,
                                      random_state=1)
plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from distutils.version import LooseVersion
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import RidgeCV
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import median_absolute_error, r2_score


# `normed` is being deprecated in favor of `density` in histograms
if LooseVersion(matplotlib.__version__) >= '2.1':
    density_param = {'density': True}
else:
    density_param = {'normed': True}
    

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)    
X, y = make_regression(n_samples=10000, noise=100, random_state=0)
y = np.exp((y + abs(y.min())) / 200)
y_trans = np.log1p(y)


f, (ax1) = plt.subplots( 1, sharey=True)

regr = RidgeCV()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)


regr_trans = TransformedTargetRegressor(regressor=RidgeCV(),
                                        func=np.log1p,
                                        inverse_func=np.expm1)
regr_trans.fit(X_train, y_train)
y_pred = regr_trans.predict(X_test)

ax1.scatter(y_test, y_pred)
ax1.plot([0, 2000], [0, 2000], '--k')
ax1.set_ylabel('Target predicted')
ax1.set_xlabel('True Target')
ax1.set_title('Ridge regression \n with target transformation')
ax1.text(100, 1750, r'$R^2$=%.2f, MAE=%.2f' % (
    r2_score(y_test, y_pred), median_absolute_error(y_test, y_pred)))
ax1.set_xlim([0, 2000])
ax1.set_ylim([0, 2000])

f.suptitle("Synthetic data", y=0.035)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-01b351c7201f> in <module>
#      18
#      19
# ---> 20 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#      21 X, y = make_regression(n_samples=10000, noise=100, random_state=0)
#      22 y = np.exp((y + abs(y.min())) / 200)
#
# /usr/local/lib64/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2182         test_size = 0.25
#    2183
# -> 2184     arrays = indexable(*arrays)
#    2185
#    2186     if shuffle is False:
#
# /usr/local/lib64/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     258         else:
#     259             result.append(np.array(X))
# --> 260     check_consistent_length(*result)
#     261     return result
#     262
#
# ...

# %%
#Генерирует данные для двоичной классификации.
#n_samples - Количество данных
#random_state - Определяет генерацию случайных чисел для создания набора данных.
X, y = datasets.make_hastie_10_2(n_samples=12000, random_state=1)
X = X.astype(np.float32)
X_train, X_test = X[:2000], X[2000:]
y_train, y_test = y[:2000], y[2000:]
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
#plt.title("make_classification")
plt.show()

# %%
#Создает набор данных в форме кривой
#n_samples -  количество точек выборки на кривой
#random_state - Определяет генерацию случайных чисел для создания набора данных.
#noise - Стандартное отклонение гауссовского шума.
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter
from sklearn import manifold, datasets
from time import time

n_samples = 300
n_components = 2
(fig, subplots) = plt.subplots(2, 2, figsize=(30, 16))
#perplexities = [5, 30, 50, 100]



X, color = datasets.samples_generator.make_s_curve(n_samples, random_state=0)

ax = subplots[1][0]
ax.scatter(X[:, 0], X[:, 2], c=color)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

for i, perplexity in enumerate(perplexities):
    ax = subplots[1][i + 1]

    t0 = time()
    tsne = manifold.TSNE(n_components=n_components, init='random',
                         random_state=0, perplexity=perplexity)
    Y = tsne.fit_transform(X)
    t1 = time()
    print("S-curve, perplexity=%d in %.2g sec" % (perplexity, t1 - t0))

    #ax.set_title("Perplexity=%d" % perplexity)
    ax.scatter(Y[:, 0], Y[:, 1], c=color)
    ax.xaxis.set_major_formatter(NullFormatter())
    ax.yaxis.set_major_formatter(NullFormatter())
    ax.axis('tight')

#plt.figure(figsize=(7, 7))
#plt.stem(idx, w[idx])
plt.title("make_sparse_coded_signal")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-49e59e650d4c> in <module>
#      24 ax.yaxis.set_major_formatter(NullFormatter())
#      25
# ---> 26 for i, perplexity in enumerate(perplexities):
#      27     ax = subplots[1][i + 1]
#      28
#
# NameError: name 'perplexities' is not defined

# %%
#Генерирует сигнал как разреженную комбинацию элементов словаря.
#Возвращает матрицу Y = DX, D(n_features, n_components), X(n_components, n_samples)
#n_samples - количество образцов для генерации
#n_components - количество компонентов в словаре
#n_features - количество функций набора данных для генерации
#n_nonzero_coefs -  количество активных (ненулевых) коэффициентов в каждой выборке
#random_state- определяет генерацию случайных чисел для создания набора данных.
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.linear_model import OrthogonalMatchingPursuitCV
from sklearn.datasets import make_sparse_coded_signal

n_components, n_features = 512, 100
n_nonzero_coefs = 17


y, X, w = make_sparse_coded_signal(n_samples=1,
                                   n_components=n_components,
                                   n_features=n_features,
                                   n_nonzero_coefs=n_nonzero_coefs,
                                   random_state=0)

y_noisy = y + 0.05 * np.random.randn(len(y))

plt.figure(figsize=(7, 7))
plt.stem(idx, w[idx])
#plt.title("make_sparse_coded_signal")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-143b5e556221> in <module>
#      25
#      26 plt.figure(figsize=(7, 7))
# ---> 27 plt.stem(idx, w[idx])
#      28 #plt.title("make_sparse_coded_signal")
#
# NameError: name 'idx' is not defined

# %%
#Создает разреженную симметричную определенную положительную матрицу.
#alpha - Вероятность того, что коэффициент равен нулю. Большие значения обеспечивают большую разреженность.
#альфа не переводится непосредственно во фракцию заполнения самой матрицы.
#smallest_coef - Значение наименьшего коэффициента.
#largest_coef - Значение наибольшего коэффициента.
#n_features - количество функций набора данных для генерации
#random_state- определяет генерацию случайных чисел для создания набора данных.
import numpy as np
from scipy import linalg
from sklearn.datasets import make_sparse_spd_matrix
from sklearn.covariance import GraphicalLassoCV, ledoit_wolf
import matplotlib.pyplot as plt

# #############################################################################
# Generate the data
n_samples = 60
n_features = 20

prng = np.random.RandomState(1)
prec = make_sparse_spd_matrix(n_features, alpha=.98,
                              smallest_coef=.4,
                              largest_coef=.7,
                              random_state=prng)
cov = linalg.inv(prec)
d = np.sqrt(np.diag(cov))
cov /= d
cov /= d[:, np.newaxis]
prec *= d
prec *= d[:, np.newaxis]
X = prng.multivariate_normal(np.zeros(n_features), cov, size=n_samples)
X -= X.mean(axis=0)
X /= X.std(axis=0)

# #############################################################################
# Estimate the covariance
emp_cov = np.dot(X.T, X) / n_samples

model = GraphicalLassoCV(cv=5)
model.fit(X)
cov_ = model.covariance_
prec_ = model.precision_

lw_cov_, _ = ledoit_wolf(X)
lw_prec_ = linalg.inv(lw_cov_)

# #############################################################################
# Plot the results
plt.figure(figsize=(20, 12))
plt.subplots_adjust(left=0.02, right=0.98)

# plot the covariances
covs = [('Empirical', emp_cov), ('Ledoit-Wolf', lw_cov_),
        ('GraphicalLassoCV', cov_), ('True', cov)]
vmax = cov_.max()
for i, (name, this_cov) in enumerate(covs):
    plt.subplot(1, 2, i + 1)
    plt.imshow(this_cov, interpolation='nearest', vmin=-vmax, vmax=vmax,
               cmap=plt.cm.RdBu_r)
    plt.xticks(())
    plt.yticks(())
    plt.title('%s covariance' % name)



# plot the model selection metric
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-c9b2fea455c4> in <module>
#      54 vmax = cov_.max()
#      55 for i, (name, this_cov) in enumerate(covs):
# ---> 56     plt.subplot(1, 2, i + 1)
#      57     plt.imshow(this_cov, interpolation='nearest', vmin=-vmax, vmax=vmax,
#      58                cmap=plt.cm.RdBu_r)
#
# /usr/local/lib64/python3.6/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# /usr/local/lib64/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
# ...

# %%
#Создает набор данных в виде рулона.
#n_samples- Количество точек выборки на кривой.
#noise - Стандартное отклонение гауссовского шума.
import time as time
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets.samples_generator import make_swiss_roll

# #############################################################################
# Generate data (swiss roll dataset)
n_samples = 1500
noise = 0.05
X, _ = make_swiss_roll(n_samples, noise)
# Make it thinner
X[:, 1] *= .5

# #############################################################################
# Compute clustering
print("Compute unstructured hierarchical clustering...")
st = time.time()
ward = AgglomerativeClustering(n_clusters=6, linkage='ward').fit(X)
elapsed_time = time.time() - st
label = ward.labels_
print("Elapsed time: %.2fs" % elapsed_time)
print("Number of points: %i" % label.size)

# #############################################################################
# Plot result
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.view_init(7, -80)
for l in np.unique(label):
    ax.scatter(X[label == l, 0], X[label == l, 1], X[label == l, 2],
               color=plt.cm.jet(np.float(l) / np.max(label + 1)),
               s=20, edgecolor='k')
plt.title('Without connectivity constraints (time %.2fs)' % elapsed_time)

plt.show()
# Out:
# Compute unstructured hierarchical clustering...
# Elapsed time: 0.05s
# Number of points: 1500
