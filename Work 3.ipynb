# %%
import numpy as np

a=np.random.random(5)


import pandas as pd
import numpy as np
data = pd.read_csv('AllD/president.csv')
data
heights = np.array(data['height(cm)'])
heights[np.newaxis,:]
# Out:
# array([[189, 170, 189, 163, 183, 171, 185, 168, 173, 183, 173, 173, 175,
#         178, 183, 193, 178, 173, 174, 183, 183, 168, 170, 178, 182, 180,
#         183, 178, 182, 188, 175, 179, 183, 193, 182, 183, 177, 185, 188,
#         188, 182, 185]])

# %%
x5=np.random.normal(0,1,(3,3))

# %%
print(x5)
# Out:
# [[ 0.8298349   0.37581564 -0.00951602]
#  [ 1.39070128  1.81387309  0.56048737]
#  [ 0.74114794 -0.23725989 -1.18012538]]

# %%
print(x5[2:,:])
# Out:
# [[ 0.74114794 -0.23725989 -1.18012538]]

# %%
print(x5[2:0,2:0])
# Out:
# []

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('AllD/president.csv')
data
heights = np.array(data['height(cm)'])
a=0
min=190
max=170
k=0
for i in range(len(heights)):
    a+=heights[i]
    if (min>heights[i]):
        min=heights[i]
    if (max<heights[i]):
        max=heights[i]
    if (heights[i]>170) & (heights[i]<190) :
        k+=1

a=a/len(heights)

print(a,"  ", max,"  ", min,"  ", k) 

np.std(heights, axis=0)
np.count_nonzero(heights > 170)
np.count_nonzero(heights < 190)
np.count_nonzero((heights > 170) & (heights < 190))

np.amax(heights, axis=0)
np.amin(heights, axis=0)
# Out:
# 179.73809523809524    193    163    35
# 163

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt


data = pd.read_csv('AllD/president.csv')

names = np.array(data['name'])


data = heights
positions = np.arange(len(heights))
s1 = pd.Series(heights)
s2 = pd.Series(names)
d = pd.DataFrame({'Gradation': s1 })
d.apply(pd.value_counts).plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9613681940>],
#       dtype=object)

# %%
data = pd.read_csv('AllD/president.csv')
data
names = np.array(data['name'])


import numpy as np
import matplotlib.pyplot as plt

data = heights
positions = np.arange(len(heights))
plt.bar(positions, data, align='center', alpha=0.5)#bar_width,
plt.xticks(positions + bar_width / 3, (names),rotation=90)
plt.show()

# %%
# !nvidia-smi
# Out:
# /usr/bin/sh: nvidia-smi: command not found
